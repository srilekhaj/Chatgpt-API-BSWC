# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

message = []
def customGPT(message):
        response = client.responses.create(
            model="gpt-5.1",
            input=message,
            temperature = 0.2
        )
        return response

message=[
    {"role": "system", "content": "All your responses must be \
        one sentence long."},
    {"role": "user", "content": "Write a story about a happy carrot."}
]

result = customGPT(message)
print(result.output_text)

# %%
token_dict ={
    "Prompt Tokens as input tokens": result.usage.input_tokens,
    "Completion Tokens  as output tokens": result.usage.output_tokens,
    "Total Tokens": result.usage.total_tokens
}
print(token_dict)
# Out:
# {'Prompt Tokens as input tokens': 28, 'Completion Tokens  as output tokens': 137, 'Total Tokens': 165}
